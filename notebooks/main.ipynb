# %%
from continual_learning import * 


if __name__ == "__main__":
    # Centralized configuration dictionary
    config = {
        "seed": 42,
        "sample_classes": [0, 1, 2,],
        "batch_size": 128,
        "learning_rate": 0.001,
        "num_epochs": 50,
        "metrics_frequency": 100,
        "dead_threshold": 0.95, 
        "corr_threshold": 0.99, 
        "saturation_threshold": 1e-4, 
        "saturation_percentage": 0.99,
        "model_type": "MLP",  # Options: "MLP", "CNN", "VisionTransformer",
        "model": {
            "input_size": 3 * 32 * 32,
            "hidden_sizes": [1024] * 10,
            "activation": "relu",
            "normalization": "layer",
            "norm_after_activation": False,
            "normalization_affine": False,
            "dropout_p": 0,
            # output_size is set dynamically based on number of sample classes
        }
    }
    
    # Initialize wandb run (specify project and optionally entity)
    wandb.init(project="CL-plasticity", config=config)
    
    # Set device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    # Set random seed for reproducibility
    def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    set_seed(config["seed"])
    
    num_classes = len(config["sample_classes"])
    
    print("Loading CIFAR10 dataset...")
    trainloader, testloader, fixed_trainloader, fixed_valloader = get_cifar10_data_with_class_selection(
        batch_size=config["batch_size"],
        sample_classes=config["sample_classes"]
    )
    
    print("Creating model...")
    if config["model_type"] == "MLP":
        config["model"]["output_size"] = num_classes
        model = MLP(**config["model"])
    model = VisionTransformer()
    # Options for CNN or VisionTransformer can be added here similarly.
    
    model = model.to(device)
    
    def module_filter(name):
        return name[-4:] == '.mlp' or 'linear' in name
    train_monitor = NetworkMonitor(model, module_filter)
    val_monitor = NetworkMonitor(model, module_filter)
    
    print("\nModel Architecture:")
    for name, module in model.named_modules():
        if len(name) > 0:
            print(f"{name}: {module.__class__.__name__}")
    
    print("\nStarting training with separate monitors...")
    history = train_with_separate_monitors(
        model, trainloader, testloader, fixed_trainloader, fixed_valloader,
        train_monitor, val_monitor,config,
        device=device
    )
    
    # Log final metrics to wandb
    wandb.log({
        "final_train_loss": history["train_losses"][-1],
        "final_test_acc": history["test_accs"][-1]
    })
    
    results_dir = './results'
    os.makedirs(results_dir, exist_ok=True)
    
    print("\nPlotting results...")
    plot_training_curves(history, save_path=results_dir)
    plot_all_metrics(history, save_path=results_dir)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: amirjoudaki. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/home/amir/Codes/NN-dynamic-scaling/code/wandb/run-20250317_163313-t3pp5a5k</code>
# Syncing run <strong><a href='https://wandb.ai/amirjoudaki/CL-plasticity/runs/t3pp5a5k' target="_blank">feasible-field-83</a></strong> to <a href='https://wandb.ai/amirjoudaki/CL-plasticity' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/amirjoudaki/CL-plasticity' target="_blank">https://wandb.ai/amirjoudaki/CL-plasticity</a>
#  View run at <a href='https://wandb.ai/amirjoudaki/CL-plasticity/runs/t3pp5a5k' target="_blank">https://wandb.ai/amirjoudaki/CL-plasticity/runs/t3pp5a5k</a>
# Using device: cuda
# Loading CIFAR10 dataset...
# Files already downloaded and verified
# Files already downloaded and verified
# Creating model...
#
# Model Architecture:
# layers: ModuleDict
# layers.patch_embed: PatchEmbedding
# layers.patch_embed.layers: ModuleDict
# layers.patch_embed.layers.proj: Conv2d
# layers.pos_drop: Dropout
# layers.block_0: TransformerBlock
# layers.block_0.layers: ModuleDict
# layers.block_0.layers.norm1: LayerNorm
# layers.block_0.layers.attn: Attention
# layers.block_0.layers.attn.layers: ModuleDict
# layers.block_0.layers.attn.layers.qkv: Linear
# layers.block_0.layers.attn.layers.attn_drop: Dropout
# layers.block_0.layers.attn.layers.proj: Linear
# layers.block_0.layers.attn.layers.proj_drop: Dropout
# layers.block_0.layers.norm2: LayerNorm
# layers.block_0.layers.mlp: TransformerMLP
# layers.block_0.layers.mlp.layers: ModuleDict
# layers.block_0.layers.mlp.layers.fc1: Linear
# layers.block_0.layers.mlp.layers.act: GELU
# layers.block_0.layers.mlp.layers.drop1: Dropout
# layers.block_0.layers.mlp.layers.fc2: Linear
# layers.block_0.layers.mlp.layers.drop2: Dropout
# layers.block_1: TransformerBlock
# layers.block_1.layers: ModuleDict
# layers.block_1.layers.norm1: LayerNorm
# layers.block_1.layers.attn: Attention
# layers.block_1.layers.attn.layers: ModuleDict
# layers.block_1.layers.attn.layers.qkv: Linear
# layers.block_1.layers.attn.layers.attn_drop: Dropout
# layers.block_1.layers.attn.layers.proj: Linear
# layers.block_1.layers.attn.layers.proj_drop: Dropout
# layers.block_1.layers.norm2: LayerNorm
# layers.block_1.layers.mlp: TransformerMLP
# layers.block_1.layers.mlp.layers: ModuleDict
# layers.block_1.layers.mlp.layers.fc1: Linear
# layers.block_1.layers.mlp.layers.act: GELU
# layers.block_1.layers.mlp.layers.drop1: Dropout
# layers.block_1.layers.mlp.layers.fc2: Linear
# layers.block_1.layers.mlp.layers.drop2: Dropout
# layers.block_2: TransformerBlock
# layers.block_2.layers: ModuleDict
# layers.block_2.layers.norm1: LayerNorm
# layers.block_2.layers.attn: Attention
# layers.block_2.layers.attn.layers: ModuleDict
# layers.block_2.layers.attn.layers.qkv: Linear
# layers.block_2.layers.attn.layers.attn_drop: Dropout
# layers.block_2.layers.attn.layers.proj: Linear
# layers.block_2.layers.attn.layers.proj_drop: Dropout
# layers.block_2.layers.norm2: LayerNorm
# layers.block_2.layers.mlp: TransformerMLP
# layers.block_2.layers.mlp.layers: ModuleDict
# layers.block_2.layers.mlp.layers.fc1: Linear
# layers.block_2.layers.mlp.layers.act: GELU
# layers.block_2.layers.mlp.layers.drop1: Dropout
# layers.block_2.layers.mlp.layers.fc2: Linear
# layers.block_2.layers.mlp.layers.drop2: Dropout
# layers.block_3: TransformerBlock
# layers.block_3.layers: ModuleDict
# layers.block_3.layers.norm1: LayerNorm
# layers.block_3.layers.attn: Attention
# layers.block_3.layers.attn.layers: ModuleDict
# layers.block_3.layers.attn.layers.qkv: Linear
# layers.block_3.layers.attn.layers.attn_drop: Dropout
# layers.block_3.layers.attn.layers.proj: Linear
# layers.block_3.layers.attn.layers.proj_drop: Dropout
# layers.block_3.layers.norm2: LayerNorm
# layers.block_3.layers.mlp: TransformerMLP
# layers.block_3.layers.mlp.layers: ModuleDict
# layers.block_3.layers.mlp.layers.fc1: Linear
# layers.block_3.layers.mlp.layers.act: GELU
# layers.block_3.layers.mlp.layers.drop1: Dropout
# layers.block_3.layers.mlp.layers.fc2: Linear
# layers.block_3.layers.mlp.layers.drop2: Dropout
# layers.block_4: TransformerBlock
# layers.block_4.layers: ModuleDict
# layers.block_4.layers.norm1: LayerNorm
# layers.block_4.layers.attn: Attention
# layers.block_4.layers.attn.layers: ModuleDict
# layers.block_4.layers.attn.layers.qkv: Linear
# layers.block_4.layers.attn.layers.attn_drop: Dropout
# layers.block_4.layers.attn.layers.proj: Linear
# layers.block_4.layers.attn.layers.proj_drop: Dropout
# layers.block_4.layers.norm2: LayerNorm
# layers.block_4.layers.mlp: TransformerMLP
# layers.block_4.layers.mlp.layers: ModuleDict
# layers.block_4.layers.mlp.layers.fc1: Linear
# layers.block_4.layers.mlp.layers.act: GELU
# layers.block_4.layers.mlp.layers.drop1: Dropout
# layers.block_4.layers.mlp.layers.fc2: Linear
# layers.block_4.layers.mlp.layers.drop2: Dropout
# layers.block_5: TransformerBlock
# layers.block_5.layers: ModuleDict
# layers.block_5.layers.norm1: LayerNorm
# layers.block_5.layers.attn: Attention
# layers.block_5.layers.attn.layers: ModuleDict
# layers.block_5.layers.attn.layers.qkv: Linear
# layers.block_5.layers.attn.layers.attn_drop: Dropout
# layers.block_5.layers.attn.layers.proj: Linear
# layers.block_5.layers.attn.layers.proj_drop: Dropout
# layers.block_5.layers.norm2: LayerNorm
# layers.block_5.layers.mlp: TransformerMLP
# layers.block_5.layers.mlp.layers: ModuleDict
# layers.block_5.layers.mlp.layers.fc1: Linear
# layers.block_5.layers.mlp.layers.act: GELU
# layers.block_5.layers.mlp.layers.drop1: Dropout
# layers.block_5.layers.mlp.layers.fc2: Linear
# layers.block_5.layers.mlp.layers.drop2: Dropout
# layers.block_6: TransformerBlock
# layers.block_6.layers: ModuleDict
# layers.block_6.layers.norm1: LayerNorm
# layers.block_6.layers.attn: Attention
# layers.block_6.layers.attn.layers: ModuleDict
# layers.block_6.layers.attn.layers.qkv: Linear
# layers.block_6.layers.attn.layers.attn_drop: Dropout
# layers.block_6.layers.attn.layers.proj: Linear
# layers.block_6.layers.attn.layers.proj_drop: Dropout
# layers.block_6.layers.norm2: LayerNorm
# layers.block_6.layers.mlp: TransformerMLP
# layers.block_6.layers.mlp.layers: ModuleDict
# layers.block_6.layers.mlp.layers.fc1: Linear
# layers.block_6.layers.mlp.layers.act: GELU
# layers.block_6.layers.mlp.layers.drop1: Dropout
# layers.block_6.layers.mlp.layers.fc2: Linear
# layers.block_6.layers.mlp.layers.drop2: Dropout
# layers.block_7: TransformerBlock
# layers.block_7.layers: ModuleDict
# layers.block_7.layers.norm1: LayerNorm
# layers.block_7.layers.attn: Attention
# layers.block_7.layers.attn.layers: ModuleDict
# layers.block_7.layers.attn.layers.qkv: Linear
# layers.block_7.layers.attn.layers.attn_drop: Dropout
# layers.block_7.layers.attn.layers.proj: Linear
# layers.block_7.layers.attn.layers.proj_drop: Dropout
# layers.block_7.layers.norm2: LayerNorm
# layers.block_7.layers.mlp: TransformerMLP
# layers.block_7.layers.mlp.layers: ModuleDict
# layers.block_7.layers.mlp.layers.fc1: Linear
# layers.block_7.layers.mlp.layers.act: GELU
# layers.block_7.layers.mlp.layers.drop1: Dropout
# layers.block_7.layers.mlp.layers.fc2: Linear
# layers.block_7.layers.mlp.layers.drop2: Dropout
# layers.block_8: TransformerBlock
# layers.block_8.layers: ModuleDict
# layers.block_8.layers.norm1: LayerNorm
# layers.block_8.layers.attn: Attention
# layers.block_8.layers.attn.layers: ModuleDict
# layers.block_8.layers.attn.layers.qkv: Linear
# layers.block_8.layers.attn.layers.attn_drop: Dropout
# layers.block_8.layers.attn.layers.proj: Linear
# layers.block_8.layers.attn.layers.proj_drop: Dropout
# layers.block_8.layers.norm2: LayerNorm
# layers.block_8.layers.mlp: TransformerMLP
# layers.block_8.layers.mlp.layers: ModuleDict
# layers.block_8.layers.mlp.layers.fc1: Linear
# layers.block_8.layers.mlp.layers.act: GELU
# layers.block_8.layers.mlp.layers.drop1: Dropout
# layers.block_8.layers.mlp.layers.fc2: Linear
# layers.block_8.layers.mlp.layers.drop2: Dropout
# layers.block_9: TransformerBlock
# layers.block_9.layers: ModuleDict
# layers.block_9.layers.norm1: LayerNorm
# layers.block_9.layers.attn: Attention
# layers.block_9.layers.attn.layers: ModuleDict
# layers.block_9.layers.attn.layers.qkv: Linear
# layers.block_9.layers.attn.layers.attn_drop: Dropout
# layers.block_9.layers.attn.layers.proj: Linear
# layers.block_9.layers.attn.layers.proj_drop: Dropout
# layers.block_9.layers.norm2: LayerNorm
# layers.block_9.layers.mlp: TransformerMLP
# layers.block_9.layers.mlp.layers: ModuleDict
# layers.block_9.layers.mlp.layers.fc1: Linear
# layers.block_9.layers.mlp.layers.act: GELU
# layers.block_9.layers.mlp.layers.drop1: Dropout
# layers.block_9.layers.mlp.layers.fc2: Linear
# layers.block_9.layers.mlp.layers.drop2: Dropout
# layers.block_10: TransformerBlock
# layers.block_10.layers: ModuleDict
# layers.block_10.layers.norm1: LayerNorm
# layers.block_10.layers.attn: Attention
# layers.block_10.layers.attn.layers: ModuleDict
# layers.block_10.layers.attn.layers.qkv: Linear
# layers.block_10.layers.attn.layers.attn_drop: Dropout
# layers.block_10.layers.attn.layers.proj: Linear
# layers.block_10.layers.attn.layers.proj_drop: Dropout
# layers.block_10.layers.norm2: LayerNorm
# layers.block_10.layers.mlp: TransformerMLP
# layers.block_10.layers.mlp.layers: ModuleDict
# layers.block_10.layers.mlp.layers.fc1: Linear
# layers.block_10.layers.mlp.layers.act: GELU
# layers.block_10.layers.mlp.layers.drop1: Dropout
# layers.block_10.layers.mlp.layers.fc2: Linear
# layers.block_10.layers.mlp.layers.drop2: Dropout
# layers.block_11: TransformerBlock
# layers.block_11.layers: ModuleDict
# layers.block_11.layers.norm1: LayerNorm
# layers.block_11.layers.attn: Attention
# layers.block_11.layers.attn.layers: ModuleDict
# layers.block_11.layers.attn.layers.qkv: Linear
# layers.block_11.layers.attn.layers.attn_drop: Dropout
# layers.block_11.layers.attn.layers.proj: Linear
# layers.block_11.layers.attn.layers.proj_drop: Dropout
# layers.block_11.layers.norm2: LayerNorm
# layers.block_11.layers.mlp: TransformerMLP
# layers.block_11.layers.mlp.layers: ModuleDict
# layers.block_11.layers.mlp.layers.fc1: Linear
# layers.block_11.layers.mlp.layers.act: GELU
# layers.block_11.layers.mlp.layers.drop1: Dropout
# layers.block_11.layers.mlp.layers.fc2: Linear
# layers.block_11.layers.mlp.layers.drop2: Dropout
# layers.norm: LayerNorm
# layers.head: Linear
#
# Starting training with separate monitors...
# Measuring baseline metrics before training...
#
# === Training Batch Metrics (before training) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  143.581, StableRank:    6.958
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  144.282, StableRank:    6.160
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  143.851, StableRank:    5.881
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  144.750, StableRank:    5.669
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  146.203, StableRank:    6.666
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  143.968, StableRank:    5.171
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.485, StableRank:    7.115
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  146.153, StableRank:    7.625
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.592, StableRank:    6.925
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.894, StableRank:    5.780
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  146.312, StableRank:    7.402
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.521, StableRank:    5.955
#
# === Validation Batch Metrics (before training) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  143.551, StableRank:    6.725
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  143.951, StableRank:    5.470
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  143.244, StableRank:    5.956
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  144.034, StableRank:    5.637
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  146.001, StableRank:    6.329
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  143.290, StableRank:    5.224
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.037, StableRank:    6.972
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.602, StableRank:    7.075
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.583, StableRank:    6.983
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.843, StableRank:    5.524
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.959, StableRank:    7.364
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, EffRank:  145.547, StableRank:    5.483
#
# Step 50: Measuring metrics...
#
# === Training Batch Metrics (step 50) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.057, EffRank:  114.520, StableRank:    3.801
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.823, EffRank:  109.422, StableRank:    3.569
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.964, EffRank:  106.815, StableRank:    2.713
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.969, EffRank:  106.121, StableRank:    2.316
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.990, EffRank:  104.193, StableRank:    2.228
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.984, EffRank:  104.614, StableRank:    2.126
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.974, EffRank:  103.611, StableRank:    2.085
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.979, EffRank:  104.396, StableRank:    2.260
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.979, EffRank:  105.051, StableRank:    2.408
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.990, EffRank:  104.007, StableRank:    2.543
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.969, EffRank:  105.168, StableRank:    2.407
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.969, EffRank:  105.337, StableRank:    2.934
#
# === Validation Batch Metrics (step 50) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.036, EffRank:  113.450, StableRank:    3.442
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.828, EffRank:  108.978, StableRank:    3.597
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.958, EffRank:  107.522, StableRank:    3.025
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.974, EffRank:  106.500, StableRank:    2.454
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  104.739, StableRank:    2.278
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.990, EffRank:  104.910, StableRank:    2.223
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.974, EffRank:  104.104, StableRank:    2.148
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.984, EffRank:  105.251, StableRank:    2.499
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.354, StableRank:    2.652
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  104.166, StableRank:    2.815
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.979, EffRank:  105.618, StableRank:    2.698
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.979, EffRank:  105.287, StableRank:    3.113
#
# Step 100: Measuring metrics...
#
# === Training Batch Metrics (step 100) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.240, EffRank:  109.571, StableRank:    3.734
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.948, EffRank:  106.330, StableRank:    3.843
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.071, StableRank:    2.840
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  103.068, StableRank:    2.684
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.760, StableRank:    2.767
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.666, StableRank:    2.768
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.080, StableRank:    2.371
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.823, StableRank:    2.838
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.473, StableRank:    2.841
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.793, StableRank:    2.774
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  104.351, StableRank:    2.710
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.278, StableRank:    3.102
#
# === Validation Batch Metrics (step 100) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.208, EffRank:  108.674, StableRank:    3.646
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.927, EffRank:  106.433, StableRank:    4.001
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.209, StableRank:    3.250
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  102.938, StableRank:    3.095
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.952, StableRank:    2.972
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.511, StableRank:    3.037
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.471, StableRank:    2.523
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.273, StableRank:    3.104
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  104.454, StableRank:    3.451
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.007, StableRank:    3.096
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.414, StableRank:    2.802
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.820, StableRank:    3.383
#
# Epoch 1/50:
# Train Loss: 0.8100 | Test Acc: 74.53%
# Time: 7.47s
#
# Step 150: Measuring metrics...
#
# === Training Batch Metrics (step 150) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.526, EffRank:  108.286, StableRank:    4.115
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.990, EffRank:  104.778, StableRank:    3.349
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.600, StableRank:    2.833
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.081, StableRank:    2.580
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.874, StableRank:    2.460
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.038, StableRank:    2.366
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.524, StableRank:    2.091
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.753, StableRank:    2.343
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.818, StableRank:    2.674
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.390, StableRank:    2.414
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.266, StableRank:    2.499
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.833, StableRank:    2.495
#
# === Validation Batch Metrics (step 150) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.516, EffRank:  107.922, StableRank:    3.657
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.990, EffRank:  104.107, StableRank:    3.360
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.096, StableRank:    2.971
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.162, StableRank:    2.750
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.076, StableRank:    2.642
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.304, StableRank:    2.512
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.297, StableRank:    2.379
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.150, StableRank:    2.760
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.965, StableRank:    2.976
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.551, StableRank:    2.676
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.153, StableRank:    2.399
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.749, StableRank:    2.511
#
# Step 200: Measuring metrics...
#
# === Training Batch Metrics (step 200) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.911, EffRank:  107.687, StableRank:    4.110
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  103.213, StableRank:    3.051
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.110, StableRank:    2.522
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.971, StableRank:    1.969
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.485, StableRank:    1.972
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.130, StableRank:    1.865
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.948, StableRank:    1.747
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.378, StableRank:    1.834
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  103.168, StableRank:    1.846
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.020, StableRank:    1.970
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.172, StableRank:    1.782
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.819, StableRank:    1.767
#
# === Validation Batch Metrics (step 200) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.870, EffRank:  107.241, StableRank:    3.839
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.979, EffRank:  103.986, StableRank:    3.236
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.567, StableRank:    2.592
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.230, StableRank:    2.350
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.907, StableRank:    2.236
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.216, StableRank:    2.083
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.662, StableRank:    1.983
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.991, StableRank:    2.036
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  103.576, StableRank:    2.133
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  100.914, StableRank:    1.912
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  102.564, StableRank:    1.841
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  104.882, StableRank:    1.834
#
# Epoch 2/50:
# Train Loss: 0.6296 | Test Acc: 72.77%
# Time: 15.09s
#
# Step 250: Measuring metrics...
#
# === Training Batch Metrics (step 250) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.724, EffRank:  107.119, StableRank:    5.800
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.969, EffRank:  102.411, StableRank:    4.245
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.718, StableRank:    2.627
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.710, StableRank:    2.366
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.248, StableRank:    2.536
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.970, StableRank:    2.207
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.035, StableRank:    2.403
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.092, StableRank:    2.844
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.466, StableRank:    3.543
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.325, StableRank:    4.564
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.217, StableRank:    5.109
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.535, StableRank:    5.699
#
# === Validation Batch Metrics (step 250) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.714, EffRank:  106.715, StableRank:    5.624
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.964, EffRank:  102.214, StableRank:    4.541
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.186, StableRank:    2.903
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.735, StableRank:    2.688
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.478, StableRank:    2.654
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.543, StableRank:    2.200
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.811, StableRank:    2.538
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.454, StableRank:    2.984
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.296, StableRank:    4.019
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.354, StableRank:    4.803
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.692, StableRank:    5.377
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  105.030, StableRank:    6.881
#
# Step 300: Measuring metrics...
#
# === Training Batch Metrics (step 300) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.880, EffRank:  106.794, StableRank:    6.181
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.688, StableRank:    3.757
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.326, StableRank:    2.597
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.801, StableRank:    2.320
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.530, StableRank:    2.417
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.130, StableRank:    2.082
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.113, StableRank:    2.043
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.575, StableRank:    2.481
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.539, StableRank:    2.918
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.090, StableRank:    2.855
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.025, StableRank:    2.932
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.714, StableRank:    3.643
#
# === Validation Batch Metrics (step 300) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.812, EffRank:  107.291, StableRank:    6.120
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.476, StableRank:    3.746
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.603, StableRank:    2.827
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.815, StableRank:    2.485
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.740, StableRank:    2.675
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.703, StableRank:    2.340
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.552, StableRank:    2.482
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.471, StableRank:    2.689
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.568, StableRank:    3.506
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.218, StableRank:    3.372
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.512, StableRank:    2.955
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.840, StableRank:    3.453
#
# Step 350: Measuring metrics...
#
# === Training Batch Metrics (step 350) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.958, EffRank:  107.364, StableRank:    5.883
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.761, StableRank:    2.746
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.341, StableRank:    2.242
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.831, StableRank:    2.069
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.422, StableRank:    1.984
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.620, StableRank:    1.843
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.096, StableRank:    1.937
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.452, StableRank:    2.088
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.522, StableRank:    2.263
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.221, StableRank:    1.914
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.908, StableRank:    1.876
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.269, StableRank:    1.863
#
# === Validation Batch Metrics (step 350) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.911, EffRank:  107.689, StableRank:    6.401
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  101.309, StableRank:    3.063
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.288, StableRank:    2.324
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.698, StableRank:    2.286
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.111, StableRank:    2.160
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.352, StableRank:    1.977
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.909, StableRank:    2.169
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.284, StableRank:    2.441
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.049, StableRank:    2.899
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.290, StableRank:    2.406
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.786, StableRank:    2.142
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.429, StableRank:    2.053
#
# Epoch 3/50:
# Train Loss: 0.5570 | Test Acc: 77.10%
# Time: 23.16s
#
# Step 400: Measuring metrics...
#
# === Training Batch Metrics (step 400) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.760, EffRank:  106.651, StableRank:    6.154
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  101.818, StableRank:    3.114
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.822, StableRank:    2.336
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.855, StableRank:    2.159
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.622, StableRank:    2.123
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.078, StableRank:    1.939
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.567, StableRank:    1.923
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.401, StableRank:    2.109
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.068, StableRank:    2.523
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.479, StableRank:    2.347
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.746, StableRank:    2.245
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.314, StableRank:    2.362
#
# === Validation Batch Metrics (step 400) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.938, EffRank:  106.640, StableRank:    6.380
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.831, StableRank:    3.398
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.723, StableRank:    2.548
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.781, StableRank:    2.440
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.486, StableRank:    2.277
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.996, StableRank:    2.020
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.821, StableRank:    2.329
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.592, StableRank:    2.273
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.799, StableRank:    2.786
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.075, StableRank:    2.490
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.613, StableRank:    2.757
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.093, StableRank:    2.582
#
# Step 450: Measuring metrics...
#
# === Training Batch Metrics (step 450) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.953, EffRank:  107.333, StableRank:    7.309
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.475, StableRank:    3.637
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.755, StableRank:    2.590
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.553, StableRank:    2.284
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.483, StableRank:    2.069
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.802, StableRank:    1.709
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.620, StableRank:    1.906
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.239, StableRank:    2.130
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.696, StableRank:    2.574
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.177, StableRank:    2.612
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.699, StableRank:    2.959
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  107.878, StableRank:    2.709
#
# === Validation Batch Metrics (step 450) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.938, EffRank:  107.839, StableRank:    7.350
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.931, StableRank:    3.908
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.935, StableRank:    2.915
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.983, StableRank:    2.544
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.509, StableRank:    2.415
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.824, StableRank:    1.919
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.416, StableRank:    2.111
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.369, StableRank:    2.447
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.784, StableRank:    3.040
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.997, StableRank:    3.151
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.542, StableRank:    3.363
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  107.371, StableRank:    3.058
#
# Epoch 4/50:
# Train Loss: 0.5010 | Test Acc: 80.93%
# Time: 30.68s
#
# Step 500: Measuring metrics...
#
# === Training Batch Metrics (step 500) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.776, EffRank:  106.159, StableRank:    5.762
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.200, StableRank:    2.552
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.910, StableRank:    2.687
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.393, StableRank:    2.539
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.357, StableRank:    2.305
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.465, StableRank:    1.825
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.016, StableRank:    1.808
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.773, StableRank:    1.991
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.734, StableRank:    2.404
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.602, StableRank:    2.020
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  107.502, StableRank:    2.145
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  107.427, StableRank:    2.066
#
# === Validation Batch Metrics (step 500) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.609, EffRank:  106.752, StableRank:    5.934
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.974, EffRank:   99.088, StableRank:    2.789
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.010, StableRank:    2.944
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.058, StableRank:    2.761
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.681, StableRank:    2.547
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.834, StableRank:    1.908
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.308, StableRank:    1.885
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.209, StableRank:    2.229
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.549, StableRank:    2.757
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.884, StableRank:    2.461
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.344, StableRank:    2.633
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.783, StableRank:    2.388
#
# Step 550: Measuring metrics...
#
# === Training Batch Metrics (step 550) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.990, EffRank:  106.228, StableRank:    6.385
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.217, StableRank:    2.993
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.333, StableRank:    2.646
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.823, StableRank:    2.630
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   95.462, StableRank:    2.493
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.907, StableRank:    2.058
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.702, StableRank:    2.219
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.176, StableRank:    2.729
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.911, StableRank:    3.259
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.680, StableRank:    3.609
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.059, StableRank:    2.538
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.907, StableRank:    2.569
#
# === Validation Batch Metrics (step 550) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.990, EffRank:  106.401, StableRank:    6.978
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.286, StableRank:    3.379
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.558, StableRank:    3.069
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.304, StableRank:    3.123
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.965, StableRank:    2.864
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.190, StableRank:    2.304
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  100.058, StableRank:    2.603
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.248, StableRank:    3.065
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.968, StableRank:    3.622
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  103.330, StableRank:    3.658
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.553, StableRank:    2.795
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.586, StableRank:    2.396
#
# Epoch 5/50:
# Train Loss: 0.4880 | Test Acc: 75.30%
# Time: 38.19s
#
# Step 600: Measuring metrics...
#
# === Training Batch Metrics (step 600) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.396, StableRank:    4.904
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.938, StableRank:    2.326
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   93.426, StableRank:    2.247
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.793, StableRank:    2.249
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   93.600, StableRank:    2.081
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.340, StableRank:    1.881
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.108, StableRank:    1.890
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.007, StableRank:    2.511
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.857, StableRank:    3.711
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  102.861, StableRank:    4.303
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.614, StableRank:    4.702
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  106.322, StableRank:    3.449
#
# === Validation Batch Metrics (step 600) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    0.995, EffRank:  105.189, StableRank:    5.094
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.737, StableRank:    2.555
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   93.940, StableRank:    2.457
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.166, StableRank:    2.782
# ...
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   92.797, StableRank:    1.762
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   87.775, StableRank:    1.557
#
# === Validation Batch Metrics (step 2050) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.251, StableRank:    8.690
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   92.851, StableRank:    2.324
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   84.570, StableRank:    2.240
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.011, StableRank:    2.700
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   87.012, StableRank:    2.672
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   93.164, StableRank:    2.062
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   92.999, StableRank:    2.483
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.006, StableRank:    2.706
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.432, StableRank:    2.812
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   93.382, StableRank:    1.954
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.282, StableRank:    1.798
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   88.223, StableRank:    1.527
#
# Step 2100: Measuring metrics...
#
# === Training Batch Metrics (step 2100) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.628, StableRank:    8.631
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   92.243, StableRank:    2.270
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   85.080, StableRank:    2.231
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   87.276, StableRank:    2.745
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   85.744, StableRank:    2.591
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.626, StableRank:    2.055
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.807, StableRank:    2.569
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.855, StableRank:    3.040
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  101.227, StableRank:    3.835
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.884, StableRank:    2.318
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.082, StableRank:    2.028
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   92.861, StableRank:    1.731
#
# === Validation Batch Metrics (step 2100) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.288, StableRank:    8.269
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.677, StableRank:    2.128
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   83.684, StableRank:    2.274
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   87.931, StableRank:    2.759
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   85.722, StableRank:    2.750
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.827, StableRank:    2.146
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.635, StableRank:    2.771
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.359, StableRank:    3.148
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.054, StableRank:    3.661
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.166, StableRank:    2.527
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.507, StableRank:    1.983
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.574, StableRank:    1.737
#
# Epoch 18/50:
# Train Loss: 0.3279 | Test Acc: 82.47%
# Time: 138.68s
#
# Step 2150: Measuring metrics...
#
# === Training Batch Metrics (step 2150) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.668, StableRank:    7.476
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.881, StableRank:    2.033
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   82.246, StableRank:    2.076
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   85.994, StableRank:    2.364
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   84.133, StableRank:    2.430
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   88.629, StableRank:    1.922
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   89.936, StableRank:    2.296
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.615, StableRank:    2.475
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   99.130, StableRank:    2.559
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.032, StableRank:    1.752
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.559, StableRank:    1.543
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   86.396, StableRank:    1.480
#
# === Validation Batch Metrics (step 2150) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  105.012, StableRank:    7.251
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.506, StableRank:    1.953
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   81.845, StableRank:    2.073
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   85.857, StableRank:    2.610
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   83.751, StableRank:    2.365
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   89.397, StableRank:    1.931
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.040, StableRank:    2.305
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   97.758, StableRank:    2.701
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   98.684, StableRank:    2.924
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   94.131, StableRank:    1.838
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   89.557, StableRank:    1.493
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   86.643, StableRank:    1.467
#
# Step 2200: Measuring metrics...
#
# === Training Batch Metrics (step 2200) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.433, StableRank:    7.317
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.522, StableRank:    2.255
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   79.146, StableRank:    1.947
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   81.868, StableRank:    2.172
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   78.159, StableRank:    2.133
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   85.016, StableRank:    1.757
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   86.559, StableRank:    2.266
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.812, StableRank:    2.604
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.476, StableRank:    2.708
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   93.563, StableRank:    2.098
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.671, StableRank:    1.918
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   88.599, StableRank:    1.583
#
# === Validation Batch Metrics (step 2200) ===
# layers.block_0.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:  104.716, StableRank:    8.641
# layers.block_1.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   90.121, StableRank:    2.428
# layers.block_2.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   78.809, StableRank:    2.041
# layers.block_3.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   81.933, StableRank:    2.389
# layers.block_4.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   78.757, StableRank:    2.373
# layers.block_5.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   85.070, StableRank:    1.763
# layers.block_6.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   86.625, StableRank:    2.754
# layers.block_7.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   95.492, StableRank:    2.839
# layers.block_8.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   96.081, StableRank:    4.292
# layers.block_9.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   93.188, StableRank:    3.629
# layers.block_10.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   91.589, StableRank:    2.288
# layers.block_11.layers.mlp: Dead:    0.000, Dup:    0.000, Saturated:    1.000, EffRank:   87.082, StableRank:    1.810
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 75
#      72         print(f"{name}: {module.__class__.__name__}")
#      74 print("\nStarting training with separate monitors...")
# ---> 75 history = train_with_separate_monitors(
#      76     model, trainloader, testloader, fixed_trainloader, fixed_valloader,
#      77     train_monitor, val_monitor,config,
#      78     device=device
#      79 )
#      81 # Log final metrics to wandb
#      82 wandb.log({
#      83     "final_train_loss": history["train_losses"][-1],
#      84     "final_test_acc": history["test_accs"][-1]
#      85 })
#
# File ~/Codes/NN-dynamic-scaling/code/continual_learning.py:1199, in train_with_separate_monitors(model, trainloader, testloader, fixed_trainloader, fixed_valloader, train_monitor, val_monitor, config, device)
#    1196 inputs, targets = inputs.to(device), targets.to(device)
#    1198 optimizer.zero_grad()
# -> 1199 outputs = model(inputs)
#    1200 loss = criterion(outputs, targets)
#    1201 loss.backward()
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Codes/NN-dynamic-scaling/code/continual_learning.py:565, in VisionTransformer.forward(self, x)
#     562 x = self.layers['pos_drop'](x)
#     564 for i in range(self.depth):
# --> 565     x = self.layers[f'block_{i}'](x)
#     567 x = self.layers['norm'](x)
#     568 x = x[:, 0]  # Use CLS token for classification
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Codes/NN-dynamic-scaling/code/continual_learning.py:492, in TransformerBlock.forward(self, x)
#     489 attn_out = self.layers['attn'](norm_x)
#     490 x = x + attn_out
# --> 492 norm_x = self.layers['norm2'](x)
#     493 mlp_out = self.layers['mlp'](norm_x)
#     494 x = x + mlp_out
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/functional.py:2900, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2890 if has_torch_function_variadic(input, weight, bias):
#    2891     return handle_torch_function(
#    2892         layer_norm,
#    2893         (input, weight, bias),
#    (...)
#    2898         eps=eps,
#    2899     )
# -> 2900 return torch.layer_norm(
#    2901     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2902 )
#
# KeyboardInterrupt:

# %%
for inputs, targets in fixed_trainloader:
    break
    
# Get the indices that would sort the targets
_, sorted_indices = torch.sort(targets)

# Use these indices to sort both inputs and targets
inputs = inputs[sorted_indices]
targets = targets[sorted_indices]

def module_filter(name):
    return True
monitor = NetworkMonitor(model, module_filter)
inputs.shape, targets.shape
monitor.register_hooks()
output = model(inputs.to('cuda'));
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
optimizer.zero_grad()
loss = criterion(output, targets.to('cuda'))
loss.backward()

monitor.activations.keys(), monitor.gradients.keys()

# %%
k = 8
X = monitor.activations['layers.linear_8'][0]
# X = X.flatten(0,1).t()
print(X.shape)
# plt.figure(figsize=(12,6))
# plt.imshow(X[:,:]); 
# X = X[::k]
Y = (X/X.norm(dim=1,keepdim=True))
C = Y @ Y.t()
# # C[C<0.95] = 0
plt.figure()
plt.imshow(C)
plt.colorbar()
X.shape, targets[::k], C.shape

# %%
layers = list(monitor.activations.keys())
for layer in layers[1::3]:
    A = monitor.activations[layer][0]
    B = monitor.gradients[layer][0]
    M = B.abs()/A.abs().mean(dim=0,keepdim=True)
    M = (M < 1e-4).float()
    M = M.mean(dim=0)
    print(f'{layer}  saturated = {len(M[M>.99]) / len(M):.2f}')
    # A.shape, G.shape

# %%
li = 8
l = model.layers[f'linear_{li}']
l2 = model.layers[f'linear_{li+1}']
in_norms = l.weight.norm(dim=1).detach().cpu()
in_grad_norms = l.weight.grad.norm(dim=1).detach().cpu()
in_bw = monitor.gradients[f'layers.linear_{li}'][0].norm(dim=0).detach().cpu()
out_norms = l2.weight.norm(dim=0).detach().cpu()
bias = l.bias.detach().cpu()

print(in_bw.shape)
plt.scatter(in_norms,out_norms);
plt.figure()
plt.scatter(in_norms,in_grad_norms);
plt.figure()
for li in range(1,10,2):
    in_bw = monitor.gradients[f'layers.linear_{li}'][0].norm(dim=0).detach().cpu()
    print((in_bw.log() - in_bw.log().mean() < -1).sum())
    sns.kdeplot(in_bw.log(), label=f'layers.linear_{li}')
plt.legend()

# %%
W = l.weight.detach().cpu()
G = l.weight.grad.detach().cpu()
M = G.abs()/W.abs().mean()
M = (M < 1e-3).float()
sns.kdeplot(M.mean(dim=1))
(M>0.95).float().mean()

# %%
A = monitor.activations[layer][0]
B = monitor.gradients[layer][0]
M = B.abs()/A.abs().mean(dim=0,keepdim=True)
M = (M < 1e-6).float()
M.mean(dim=0).shape, layer, M.mean(dim=0)[:5]

# %%
import seaborn as sns

L = list(monitor.gradients.keys())[::-1][2:30:3]

for l in L:
    G = monitor.gradients[l][0]
    feature_grad_norms = G.norm(dim=0)
    batch_grad_norms = G.norm(dim=1)
    print(l, G.shape, feature_grad_norms.shape, batch_grad_norms.shape)
    sns.kdeplot(feature_grad_norms.log(),label=l,)
plt.legend()

# %%
X = train_monitor.gradients['layers.norm_9'][0]
# plt.hist(X.flatten())
for f in range(10):
    plt.hist(X[:,f],label=f'feature {f}',alpha=0.5)
plt.legend()

plt.figure()
for b in [0,1]:
    plt.hist(X[b,:],label=f'batch {b}',alpha=0.5)
plt.legend()
X.shape
